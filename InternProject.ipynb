# %% [markdown]
# ### Importing Libraries and Preprocessing

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import *
from nltk.stem import WordNetLemmatizer
import string
import matplotlib.pyplot as plt
import pickle
from sklearn.metrics import accuracy_score,confusion_matrix,roc_auc_score,classification_report,roc_curve,ConfusionMatrixDisplay
#nltk.download('all')

# %%
df = pd.read_excel('bepec_p.xlsx',engine='openpyxl')
df.columns=['Description','Target']
df.head()
# Out:
#                                          Description  Target
# 0                              Php,  python,  js,  c    Good
# 1                                       Python and R    Good
# 2                                                 No  Novice
# 3                                            Not yet  Novice
# 4  Yes I had experience in C, C++, and python but...  Novice

# %%
df.describe(include='O')
# Out:
#        Description  Target
# count          390     391
# unique         223       4
# top             No  Novice
# freq            61     169

# %%
df.isnull().sum()
# Out:
# Description    7
# Target         6
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Description    0
# Target         0
# dtype: int64

# %%
df.Target.value_counts()
# Out:
# Novice     168
# Average    147
# Good        74
# Na           1
# Name: Target, dtype: int64

# %%
index = df[df['Target']=='Na'].index
df.drop(index,inplace=True)

# %%
df.Target.value_counts()
# Out:
# Novice     168
# Average    147
# Good        74
# Name: Target, dtype: int64

# %% [markdown]
# ### NLP Techniques

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def preprocessing_step(sentence):
    sentence = sentence.lower()
    cleanr = re.compile('<.*?>')
    sentence = re.sub(r'[0-9]', '', sentence, re.I|re.A) #Removing Numbers
    sentence = re.sub(r'[^a-zA-Z0-9\s]', ' ', sentence) ##Removing punctuations
    sentence = sentence.lower()
    stopwords_set = set(stopwords.words('english'))
    stopwords_filtered = [word for word in stopwords_set if word not in ["not","no","nor","don't","aren't","couldn't", "didn't", "doesn't", "hadn't", "hasn't", "haven't","isn't","mightn't","mustn't",  "needn't","shouldn't","wasn't","weren't","won't","wouldn't"]]
    preprocessed = [word for word in sentence.split(',') if not word in stopwords_filtered]
    #preprocessed = ''.join(preprocessed)
    return preprocessed

# %%
processed_list=[]
lemmatizer = WordNetLemmatizer()
for each_description in df['Description']:
    processed=preprocessing_step(each_description)
    processed_list.append(processed)

# %%
df['Preprocessed_Description'] = processed_list

# %%
final_df=pd.DataFrame()
final_df['Description']=df['Preprocessed_Description'].astype(str)
final_df['Target'] = df['Target']

# %%
from wordcloud import WordCloud
wc=WordCloud(width=2000,height=2000,background_color='white')
wc = wc.generate(final_df[final_df['Target']=='Good']['Description'].str.cat(sep=" "))
plt.imshow(wc)

# %%
from wordcloud import WordCloud
wc=WordCloud(width=2000,height=2000,background_color='white')
wc = wc.generate(final_df[final_df['Target']=='Average']['Description'].str.cat(sep=" "))
plt.imshow(wc)

# %%
from wordcloud import WordCloud
wc=WordCloud(width=2000,height=2000,background_color='white')
wc = wc.generate(final_df[final_df['Target']=='Novice']['Description'].str.cat(sep=" "))
plt.imshow(wc)

# %%
def get_rank(x):
    if x=='Novice':
        return 0
    elif x=='Average':
        return 1
    elif x=='Good':
        return 2
    else:
        return None
    

y=final_df['Target'].apply(lambda x: get_rank(x))

# %% [markdown]
# #### Model Building

# %%
corpus=[]
for each_description in final_df['Description']:
    processed=''.join(each_description)
    processed=processed[2:-2]
    corpus.append(processed)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense,Dropout
from numpy.random import seed

# %%
from numpy.random import seed
seed(1)
tf.random.set_seed(2)

# %%
onehot_repr=[one_hot(words,50)for words in corpus]

# %%
sent_length=20
embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[ 0  0  0 ... 46 19  3]
#  [ 0  0  0 ... 46  7 18]
#  [ 0  0  0 ...  0  0 11]
#  ...
#  [ 0  0  0 ...  0  0 31]
#  [ 0  0  0 ...  0  0 42]
#  [ 0  0  0 ...  0  0 11]]

# %%
len(embedded_docs),y.shape
# Out:
# (389, (389,))

# %% [markdown]
# ##### Model Architecture

# %%
embedding_vector_features=40
model=Sequential()
model.add(Embedding(50,embedding_vector_features,input_length=sent_length))
model.add(LSTM(128,return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(64))
model.add(Dense(32,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(3,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 40)            2000
#
#  lstm (LSTM)                 (None, 20, 128)           86528
#
#  dropout (Dropout)           (None, 20, 128)           0
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 140,115
# Trainable params: 140,115
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
X_final=np.array(embedded_docs)
y_final=np.array(y)

# %%
X_final.shape,y_final.shape
# Out:
# ((389, 20), (389,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size=0.33, random_state=42)

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 6s 197ms/step - loss: 1.0882 - accuracy: 0.3962 - val_loss: 1.0613 - val_accuracy: 0.3256
# Epoch 2/100
# 9/9 [==============================] - 0s 28ms/step - loss: 1.0616 - accuracy: 0.3885 - val_loss: 1.0260 - val_accuracy: 0.4574
# Epoch 3/100
# 9/9 [==============================] - 0s 27ms/step - loss: 1.0617 - accuracy: 0.4231 - val_loss: 1.0324 - val_accuracy: 0.5116
# Epoch 4/100
# 9/9 [==============================] - 0s 33ms/step - loss: 1.0557 - accuracy: 0.4269 - val_loss: 1.0318 - val_accuracy: 0.5116
# Epoch 5/100
# 9/9 [==============================] - 0s 28ms/step - loss: 1.0491 - accuracy: 0.4077 - val_loss: 1.0240 - val_accuracy: 0.7209
# Epoch 6/100
# 9/9 [==============================] - 0s 26ms/step - loss: 1.0564 - accuracy: 0.4423 - val_loss: 1.0358 - val_accuracy: 0.3256
# Epoch 7/100
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0517 - accuracy: 0.4385 - val_loss: 1.0541 - val_accuracy: 0.3256
# Epoch 8/100
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0546 - accuracy: 0.4462 - val_loss: 1.0336 - val_accuracy: 0.3256
# Epoch 9/100
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0310 - accuracy: 0.4308 - val_loss: 0.9944 - val_accuracy: 0.3798
# Epoch 10/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.9966 - accuracy: 0.4500 - val_loss: 0.9407 - val_accuracy: 0.6977
# Epoch 11/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.9438 - accuracy: 0.5577 - val_loss: 0.8392 - val_accuracy: 0.5504
# Epoch 12/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.8658 - accuracy: 0.5500 - val_loss: 0.8091 - val_accuracy: 0.7364
# Epoch 13/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.8176 - accuracy: 0.6192 - val_loss: 0.7628 - val_accuracy: 0.7752
# Epoch 14/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.7409 - accuracy: 0.7115 - val_loss: 0.5756 - val_accuracy: 0.8140
# Epoch 15/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.6573 - accuracy: 0.7192 - val_loss: 0.5541 - val_accuracy: 0.7984
# Epoch 16/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6119 - accuracy: 0.7462 - val_loss: 0.4766 - val_accuracy: 0.8217
# Epoch 17/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5980 - accuracy: 0.7538 - val_loss: 0.5178 - val_accuracy: 0.7829
# Epoch 18/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.5737 - accuracy: 0.7654 - val_loss: 0.4895 - val_accuracy: 0.7984
# Epoch 19/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6104 - accuracy: 0.7577 - val_loss: 0.5212 - val_accuracy: 0.7442
# Epoch 20/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.5557 - accuracy: 0.7846 - val_loss: 0.4736 - val_accuracy: 0.8217
# Epoch 21/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5443 - accuracy: 0.8115 - val_loss: 0.4568 - val_accuracy: 0.8217
# Epoch 22/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5405 - accuracy: 0.8038 - val_loss: 0.4778 - val_accuracy: 0.7597
# Epoch 23/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5009 - accuracy: 0.7885 - val_loss: 0.4602 - val_accuracy: 0.7984
# Epoch 24/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4837 - accuracy: 0.8000 - val_loss: 0.4506 - val_accuracy: 0.7984
# Epoch 25/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4885 - accuracy: 0.8269 - val_loss: 0.5001 - val_accuracy: 0.7519
# Epoch 26/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4856 - accuracy: 0.8115 - val_loss: 0.4507 - val_accuracy: 0.8140
# Epoch 27/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4694 - accuracy: 0.8346 - val_loss: 0.4559 - val_accuracy: 0.8140
# Epoch 28/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4337 - accuracy: 0.8385 - val_loss: 0.4548 - val_accuracy: 0.8140
# Epoch 29/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4158 - accuracy: 0.8538 - val_loss: 0.5091 - val_accuracy: 0.7829
# Epoch 30/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4386 - accuracy: 0.8500 - val_loss: 0.4365 - val_accuracy: 0.8217
# Epoch 31/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4241 - accuracy: 0.8462 - val_loss: 0.4432 - val_accuracy: 0.8140
# Epoch 32/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4067 - accuracy: 0.8654 - val_loss: 0.4429 - val_accuracy: 0.8217
# Epoch 33/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4220 - accuracy: 0.8615 - val_loss: 0.4338 - val_accuracy: 0.8140
# Epoch 34/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3838 - accuracy: 0.8808 - val_loss: 0.4345 - val_accuracy: 0.8062
# Epoch 35/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3531 - accuracy: 0.8846 - val_loss: 0.5015 - val_accuracy: 0.8062
# Epoch 36/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3366 - accuracy: 0.8885 - val_loss: 0.4667 - val_accuracy: 0.8217
# Epoch 37/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3483 - accuracy: 0.8654 - val_loss: 0.4621 - val_accuracy: 0.7984
# Epoch 38/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3323 - accuracy: 0.8885 - val_loss: 0.4719 - val_accuracy: 0.8140
# Epoch 39/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.3153 - accuracy: 0.8923 - val_loss: 0.4929 - val_accuracy: 0.8217
# Epoch 40/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3139 - accuracy: 0.8962 - val_loss: 0.5076 - val_accuracy: 0.7984
# Epoch 41/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3176 - accuracy: 0.8846 - val_loss: 0.5173 - val_accuracy: 0.8140
# Epoch 42/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3471 - accuracy: 0.8808 - val_loss: 0.4822 - val_accuracy: 0.8062
# Epoch 43/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3154 - accuracy: 0.9077 - val_loss: 0.5017 - val_accuracy: 0.8062
# Epoch 44/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2940 - accuracy: 0.8846 - val_loss: 0.5384 - val_accuracy: 0.8062
# Epoch 45/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2909 - accuracy: 0.8923 - val_loss: 0.5392 - val_accuracy: 0.7829
# Epoch 46/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2979 - accuracy: 0.9038 - val_loss: 0.5280 - val_accuracy: 0.7907
# Epoch 47/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.3027 - accuracy: 0.9000 - val_loss: 0.4717 - val_accuracy: 0.8062
# Epoch 48/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2876 - accuracy: 0.9000 - val_loss: 0.5049 - val_accuracy: 0.7907
# Epoch 49/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2776 - accuracy: 0.9038 - val_loss: 0.5518 - val_accuracy: 0.7907
# Epoch 50/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3298 - accuracy: 0.8769 - val_loss: 0.5169 - val_accuracy: 0.8217
# Epoch 51/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2524 - accuracy: 0.9192 - val_loss: 0.5247 - val_accuracy: 0.8062
# Epoch 52/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2583 - accuracy: 0.8962 - val_loss: 0.5621 - val_accuracy: 0.7907
# Epoch 53/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2632 - accuracy: 0.9192 - val_loss: 0.5733 - val_accuracy: 0.8062
# Epoch 54/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2390 - accuracy: 0.9077 - val_loss: 0.5770 - val_accuracy: 0.7984
# Epoch 55/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2415 - accuracy: 0.9231 - val_loss: 0.5748 - val_accuracy: 0.7829
# Epoch 56/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2403 - accuracy: 0.9154 - val_loss: 0.6048 - val_accuracy: 0.7984
# Epoch 57/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2309 - accuracy: 0.9231 - val_loss: 0.6513 - val_accuracy: 0.7752
# Epoch 58/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2324 - accuracy: 0.9269 - val_loss: 0.6350 - val_accuracy: 0.8140
# Epoch 59/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2210 - accuracy: 0.9231 - val_loss: 0.5621 - val_accuracy: 0.7984
# Epoch 60/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2388 - accuracy: 0.9077 - val_loss: 0.5090 - val_accuracy: 0.8217
# Epoch 61/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2277 - accuracy: 0.9231 - val_loss: 0.5401 - val_accuracy: 0.7984
# Epoch 62/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2083 - accuracy: 0.9308 - val_loss: 0.6027 - val_accuracy: 0.8140
# Epoch 63/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2058 - accuracy: 0.9269 - val_loss: 0.6144 - val_accuracy: 0.7829
# Epoch 64/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2292 - accuracy: 0.9308 - val_loss: 0.5760 - val_accuracy: 0.7829
# Epoch 65/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2110 - accuracy: 0.9308 - val_loss: 0.5683 - val_accuracy: 0.8295
# Epoch 66/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1836 - accuracy: 0.9346 - val_loss: 0.6148 - val_accuracy: 0.8140
# Epoch 67/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1912 - accuracy: 0.9462 - val_loss: 0.6445 - val_accuracy: 0.8062
# Epoch 68/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1877 - accuracy: 0.9346 - val_loss: 0.6538 - val_accuracy: 0.7984
# Epoch 69/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1719 - accuracy: 0.9538 - val_loss: 0.6782 - val_accuracy: 0.8140
# Epoch 70/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1454 - accuracy: 0.9577 - val_loss: 0.7473 - val_accuracy: 0.8140
# Epoch 71/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1720 - accuracy: 0.9500 - val_loss: 0.7380 - val_accuracy: 0.7984
# Epoch 72/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1645 - accuracy: 0.9500 - val_loss: 0.7375 - val_accuracy: 0.7907
# Epoch 73/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1625 - accuracy: 0.9500 - val_loss: 0.7586 - val_accuracy: 0.8062
# Epoch 74/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1600 - accuracy: 0.9538 - val_loss: 0.7618 - val_accuracy: 0.8140
# Epoch 75/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1419 - accuracy: 0.9538 - val_loss: 0.8317 - val_accuracy: 0.8140
# Epoch 76/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1507 - accuracy: 0.9423 - val_loss: 0.8198 - val_accuracy: 0.8217
# Epoch 77/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1480 - accuracy: 0.9500 - val_loss: 0.7761 - val_accuracy: 0.8062
# Epoch 78/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1513 - accuracy: 0.9462 - val_loss: 0.7824 - val_accuracy: 0.8295
# Epoch 79/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2885 - accuracy: 0.9154 - val_loss: 0.7045 - val_accuracy: 0.8062
# Epoch 80/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1900 - accuracy: 0.9462 - val_loss: 0.7749 - val_accuracy: 0.8217
# Epoch 81/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1668 - accuracy: 0.9423 - val_loss: 0.8238 - val_accuracy: 0.8140
# Epoch 82/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1519 - accuracy: 0.9577 - val_loss: 0.7748 - val_accuracy: 0.8295
# Epoch 83/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1630 - accuracy: 0.9500 - val_loss: 0.8306 - val_accuracy: 0.8217
# Epoch 84/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1489 - accuracy: 0.9500 - val_loss: 0.8129 - val_accuracy: 0.8140
# Epoch 85/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1670 - accuracy: 0.9577 - val_loss: 0.7944 - val_accuracy: 0.8372
# Epoch 86/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1426 - accuracy: 0.9538 - val_loss: 0.8098 - val_accuracy: 0.8217
# Epoch 87/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1288 - accuracy: 0.9577 - val_loss: 0.8068 - val_accuracy: 0.8217
# Epoch 88/100
# 9/9 [==============================] - 0s 21ms/step - loss: 0.1440 - accuracy: 0.9538 - val_loss: 0.8482 - val_accuracy: 0.8140
# Epoch 89/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1454 - accuracy: 0.9462 - val_loss: 0.8024 - val_accuracy: 0.8450
# Epoch 90/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1720 - accuracy: 0.9538 - val_loss: 0.8222 - val_accuracy: 0.8140
# Epoch 91/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1485 - accuracy: 0.9423 - val_loss: 0.8130 - val_accuracy: 0.8372
# Epoch 92/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1706 - accuracy: 0.9577 - val_loss: 0.7727 - val_accuracy: 0.8450
# Epoch 93/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1794 - accuracy: 0.9346 - val_loss: 0.7189 - val_accuracy: 0.8295
# Epoch 94/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1491 - accuracy: 0.9538 - val_loss: 0.7321 - val_accuracy: 0.8217
# Epoch 95/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1550 - accuracy: 0.9538 - val_loss: 0.7221 - val_accuracy: 0.8450
# Epoch 96/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1303 - accuracy: 0.9538 - val_loss: 0.7337 - val_accuracy: 0.8372
# Epoch 97/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1458 - accuracy: 0.9538 - val_loss: 0.7554 - val_accuracy: 0.8295
# Epoch 98/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1633 - accuracy: 0.9346 - val_loss: 0.8502 - val_accuracy: 0.8217
# Epoch 99/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1388 - accuracy: 0.9500 - val_loss: 0.8282 - val_accuracy: 0.8372
# Epoch 100/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1484 - accuracy: 0.9615 - val_loss: 0.7860 - val_accuracy: 0.8372

# %%
predicted = model.predict(X_test)
# Out:
# 5/5 [==============================] - 1s 5ms/step

# %%
predicted_labels=[np.argmax(i) for i in predicted]
expected_labels=[np.argmax(i) for i in y_test]

# %%
result=pd.DataFrame()
result['Expected']=expected_labels
result['Predicted']=predicted_labels
result
# Out:
#      Expected  Predicted
# 0           2          2
# 1           0          0
# 2           0          0
# 3           0          2
# 4           2          2
# ..        ...        ...
# 124         1          1
# 125         0          0
# 126         0          1
# 127         0          2
# 128         0          0
#
# [129 rows x 2 columns]

# %%
def custom_confusion_matrix(df: pd.DataFrame, col1: str, col2: str):

    return (
            df
            .groupby([col1, col2])
            .size()
            .unstack(fill_value=0)
            )

# %%
cm=custom_confusion_matrix(result, 'Expected','Predicted')

# %%
import seaborn as sns
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Expected')
# Out:
# Text(95.72222222222221, 0.5, 'Expected')

# %%
model.save('model_lstm.h5')

# %%
corpus=['yes']
sent_length=20
onehot_repr_test =[one_hot(words,50)for words in corpus] 

embedded_docs_test=pad_sequences(onehot_repr_test,padding='pre',maxlen=sent_length)

exp_test=model.predict(embedded_docs_test)
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
predicted_labels=[np.argmax(i) for i in exp_test]
print(type(predicted_labels),predicted_labels)
# Out:
# <class 'list'> [1]

# %%
predicted_label=str(predicted_labels)
predicted_label[1]
# Out:
# '1'

# %%
from tensorflow.keras.models import load_model
corpus = ['Php, python, js, c']
print(type(corpus))
model2 = load_model('model_lstm.h5')
sent_length=20
onehot_repr=[one_hot(words,50)for words in corpus] 
embedded_docs_test= pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
prediction=model2.predict(embedded_docs_test)
predicted_labels=[np.argmax(i) for i in prediction]
predicted_labels="".join(str(x) for x in predicted_labels)
predicted_labels=int(predicted_labels)
if predicted_labels==0:
    print()
    print('''He/She is newbie to Programming''')
elif predicted_labels==1:
     print('''He/She is average to Programming''')       
else:
    print('''He/She is rockstar to Programming''')
# Out:
# <class 'list'>
# 1/1 [==============================] - 1s 514ms/step
# He/She is rockstar to Programming
